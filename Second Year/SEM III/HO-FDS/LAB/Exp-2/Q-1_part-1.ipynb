# %%
import numpy as np
heights=[168,170,150,160,182,140,175,191,152,150]

# %%
mean=np.mean(heights)
print(mean)
# Out:
# 163.8

# %%
heights.sort()

# %%
print(heights)
# Out:
# [140, 150, 150, 152, 160, 168, 170, 175, 182, 191]

# %%
median=np.median(heights)

# %%
print(median)
# Out:
# 164.0

# %%
heights_new=[168,170,150,160,182,140,175,191,152]

# %%
heights_new.sort()

# %%
print(heights_new)
# Out:
# [140, 150, 152, 160, 168, 170, 175, 182, 191]

# %%
median=np.median(heights_new)

# %%
print(median)
# Out:
# 168.0

# %%
import statistics as stats
stats.mode(heights)
# Out:
# 150

# %%
np.var(heights)
# Out:
# 235.35999999999999

# %%
std=np.std(heights)

# %%
print(std)
# Out:
# 15.341447128612085
